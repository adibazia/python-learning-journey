# %% [markdown]
# # Python 30 Days Challenge

# %% [markdown]
# ## Day 9 - String Methods & Python Modules

# %% [markdown]
# ### Topics Covered
#
# - Python Strings
# - String Methods
# - Python Modules
# - Real-World Mini Projects

# %%
name = "Adiba Zia"
age = 18 
Uni = "GCU"
print("name:",name)
print("age:",age)
print("Uni:",Uni)
# Out:
# name: Adiba Zia
# age: 18
# Uni: GCU

# %%
name = "Adiba"
print(name.upper())
# Out:
# ADIBA

# %%
name = "ADIBA"
print(name.lower())
# Out:
# adiba

# %%
employee_name = input("Enter Employee Name : ")

print(employee_name.upper())
# Out:
# Enter Employee Name :  adiba zia
# ADIBA ZIA

# %%
university = input("Enter University Name : ")

print(university.upper())
# Out:
# Enter University Name :  government uni lahore
# GOVERNMENT UNI LAHORE

# %%
email = input("Enter Email : ")

print(email.lower())
# Out:
# Enter Email :  AdibaZiA**@gmail.com
# adibazia**@gmail.com

# %%
student = input("Enter Student Name : ")

print(student.title())
# Out:
# Enter Student Name :  adiba zia ul haq
# Adiba Zia Ul Haq

# %%
city = "lahore"

print(city.capitalize())
# Out:
# Lahore

# %%
name = "   Zobia Zaheer   "

print(name.strip())
# Out:
# Zobia Zaheer

# %%
username = input("Enter Username : ")

print(username.strip())
# Out:
# Enter Username :  Zobia Zaheer
# Zobia Zaheer

# %%
message = "I Love Java"

print(message.replace("Java", "Python"))
# Out:
# I Love Python

# %%
company = "ABC Software"

print(company.replace("ABC", "NAK"))
# Out:
# NAK Software

# %%
sentence = "I am learning Python"

print(sentence.split())
# Out:
# ['I', 'am', 'learning', 'Python']

# %% [markdown]
# ### Advanced String Methods

# %%
sentence = "I Love Python"

print(sentence.find("Python"))
# Out:
# 7

# %%
message = input("Enter Message : ")

print(message.find("Python"))
# Out:
# Enter Message :  Python is easy
# 0

# %%
sentence = "Python Python Java Python"

print(sentence.count("Python"))
# Out:
# 3

# %%
website = "https://google.com"

print(website.startswith("https"))
# Out:
# True

# %%
url = input("Enter Website : ")

print(url.startswith("https"))
# Out:
# Enter Website :  googledrive:\not
# False

# %%
email = "student@gmail.com"

print(email.endswith(".com"))
# Out:
# True

# %%
email = input("Enter Email : ")

print(email.endswith(".com"))
# Out:
# Enter Email :  Zobiazaheer@gmail.com
# True

# %%
name = "Zobia"

print(len(name))
# Out:
# 5

# %%
password = input("Enter Password : ")

print("Password Length :", len(password))
# Out:
# Enter Password :  ksjfoi389483h'oidhfk
# Password Length : 20

# %% [markdown]
# #### User Registration System

# %%
name = input("Enter Your Name : ")
email = input("Enter Your Email : ")
password = input("Create Password : ")

print("\nUser Information")

print("Name :", name.title())
print("Email :", email.lower())
print("Password Length :", len(password))
print("Valid Email :", email.endswith(".com"))
# Out:
# Enter Your Name :  Adiba Zia
# Enter Your Email :  adibazia**@gmail.com
# Create Password :  dhfueieou4549c|9353ojr
# User Information
# Name : Adiba Zia
# Email : adibazia**@gmail.com
# Password Length : 22
# Valid Email : True

# %% [markdown]
# ## Python Modules

# %%
import math

print(math.sqrt(81))
# Out:
# 9.0

# %%
import math

print(math.pow(5,2))
# Out:
# 25.0

# %%
import math

print(math.ceil(7.2))
# Out:
# 8

# %%
import math

number = int(input("Enter Number : "))

print("Square Root :", math.sqrt(number))

print("Square :", math.pow(number,2))
# Out:
# Enter Number :  36
# Square Root : 6.0
# Square : 1296.0

# %%
import math

print("Math Calculator")

number = float(input("Enter a Number : "))

print()

print("Results")

print("Square Root :", math.sqrt(number))

print("Square :", math.pow(number, 2))

print("Ceiling Value :", math.ceil(number))

print("Floor Value :", math.floor(number))
# Out:
# Math Calculator
# Enter a Number :  90
# Results
# Square Root : 9.486832980505138
# Square : 8100.0
# Ceiling Value : 90
# Floor Value : 90

# %% [markdown]
# ### Random module

# %%
import random

print(random.randint(1, 10))
# Out:
# 6

# %%
import random

print(random.randint(1, 10))
# Out:
# 7

# %%
import random

print(random.randint(1, 10))
# Out:
# 9

# %%
import random

otp = random.randint(1000, 9999)

print("Your OTP is :", otp)
# Out:
# Your OTP is : 5555

# %% [markdown]
# ## Mini Projects
# ### Dice Simulator

# %%
import random

print("Dice Simulator")

dice = random.randint(1, 6)

print("Dice Number :", dice)
# Out:
# Dice Simulator
# Dice Number : 3

# %%
import random

print("Dice Simulator")

dice = random.randint(1, 6)

print("Dice Number :", dice)
# Out:
# Dice Simulator
# Dice Number : 5

# %%
import random

print("Dice Simulator")

dice = random.randint(1, 6)

print("Dice Number :", dice)
# Out:
# Dice Simulator
# Dice Number : 6

# %%
import random

colors = ["Red", "Blue", "Green", "Black"]

print(random.choice(colors))
# Out:
# Blue

# %% [markdown]
# ### Lucky Draw Winner

# %%
import random

participants = [

    "Ali",
    "Ahmed",
    "Sara",
    "Zobia",
    "Fatima"

]

winner = random.choice(participants)

print("Lucky Draw Winner :", winner)
# Out:
# Lucky Draw Winner : Ahmed

# %%
import random

students = [

    "Ali",
    "Ahmed",
    "Sara",
    "Zobia",
    "Ayesha"

]

selected = random.choice(students)

print("Today's Presenter")

print(selected)
# Out:
# Today's Presenter
# Zobia

# %% [markdown]
# ### Rock Paper Scissors

# %%
import random

choices = [

    "Rock",
    "Paper",
    "Scissors"

]

computer = random.choice(choices)

print("Computer Chose :", computer)
# Out:
# Computer Chose : Paper

# %%
import random

numbers = [

    1,
    2,
    3,
    4,
    5

]

random.shuffle(numbers)

print(numbers)
# Out:
# [4, 3, 5, 2, 1]

# %%
import random

questions = [

    "Python",
    "Java",
    "C++",
    "JavaScript"

]

random.shuffle(questions)

print(questions)
# Out:
# ['Java', 'JavaScript', 'Python', 'C++']

# %%
import random

print("Welcome To Lucky Draw")

participants = [

    "Ali",
    "Ahmed",
    "Sara",
    "Zobia",
    "Ayesha",
    "Fatima"

]

winner = random.choice(participants)

print()

print("Congratulations!")

print("Winner :", winner)
# Out:
# Welcome To Lucky Draw
#
# Congratulations!
# Winner : Zobia

# %%
import random

print("Welcome To Lucky Draw")

participants = [

    "Ali",
    "Ahmed",
    "Sara",
    "Zobia",
    "Ayesha",
    "Fatima"

]

winner = random.choice(participants)

print()

print("Congratulations!")

print("Winner :", winner)
# Out:
# Welcome To Lucky Draw
#
# Congratulations!
# Winner : Fatima

# %% [markdown]
# ### Day time module

# %%
import datetime

today = datetime.datetime.now()

print(today)
# Out:
# 2026-08-06 00:22:22.237503

# %%
import datetime

today = datetime.datetime.now()

print(today.date())
# Out:
# 2026-08-06

# %%
import datetime

today = datetime.datetime.now()

print(today.time())
# Out:
# 00:22:53.985920

# %%
import datetime

today = datetime.datetime.now()

print(today.day)
# Out:
# 6

# %%
import datetime

today = datetime.datetime.now()

print("Meezan Bank")

print("Transaction Successful")

print("Date :", today.date())

print("Time :", today.time())
# Out:
# Meezan Bank
# Transaction Successful
# Date : 2026-08-06
# Time : 00:23:28.367285

# %%
import datetime

today = datetime.datetime.now()

print("ABC Bank")

print("Transaction Successful")

print("Date :", today.date())

print("Time :", today.time())
# Out:
# ABC Bank
# Transaction Successful
# Date : 2026-08-06
# Time : 00:23:37.304685

# %%
import datetime

birth_year = int(input("Enter Birth Year : "))

current_year = datetime.datetime.now().year

age = current_year - birth_year

print()

print("Your Age is :", age)
# Out:
# Enter Birth Year :  2007
# Your Age is : 19

# %%
import datetime

today = datetime.datetime.now()

print("Today's Date")

print(today.date())

print()

print("Current Time")

print(today.time())
# Out:
# Today's Date
# 2026-08-06
#
# Current Time
# 00:24:06.643416

# %%
import random
import datetime

print("Student ID Card")

name = input("Enter Student Name : ")
department = input("Enter Department : ")

student_id = random.randint(10000,99999)

today = datetime.datetime.now()

print()

print("Student Information")

print("Student ID :", student_id)

print("Name :", name.title())

print("Department :", department.title())

print("Issue Date :", today.date())

print("Issue Time :", today.time())
# Out:
# Student ID Card
# Enter Student Name :  Adiba Zia
# Enter Department :  Mathematics
# Student Information
# Student ID : 87616
# Name : Adiba Zia
# Department : Mathematics
# Issue Date : 2026-08-06
# Issue Time : 00:24:26.396809
