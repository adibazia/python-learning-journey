# %% [markdown]
# # PYTHON 30 DAYS CHALLENGE

# %% [markdown]
# ## DAY 2

# %%
name = "Adiba Zia"
age =  18
city = "Lahore"

print(name)
print(age)
print(city)
# Out:
# Adiba Zia
# 18
# Lahore

# %%
Name = "Adiba Zia"
Age = 18 
City = "Lahore"

print("Name:", name )
print("Age:", age)
print("City:", city)
# Out:
# Name: Adiba Zia
# Age: 18
# City: Lahore

# %%
Name = "Adiba Zia"
Age = 18 
City = "Lahore"
Height = 5.2
Student = True

print(type(name)) 
print(type(age))
print(type(city))
print(type(Height))
print(type(Student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
Name = input("Enter your name:  ")
Age = input("Enter your age:  ")

print("Hi,", name)
print("Whats your age:", age)
# Out:
# Enter your name:   Adiba Zia
# Enter your age:   18
# Hi, Adiba Zia
# Whats your age: 18

# %%
name = input("Enter your name:  ")

print("What are you doing," , name)
# Out:
# Enter your name:   Adiba Zia
# What are you doing, Adiba Zia

# %%
Name =             input("Enter your name:  ")
Age =              input("Enter your age:  ")
University =       input("Univeristy name:  ")
Semester =         input("Enter your Semester:  ")

print("""
**********************************
      Student Information
**********************************

Name:,Name
Age:age
University:University
Semester: semester 

**********************************
          Thank you
********************************** 
""")
# Out:
# Enter your name:   Adiba Zia
# Enter your age:   18
# Univeristy name:   GCU
# Enter your Semester:   1st
# **********************************
#       Student Information
# **********************************
#
# Name:,Name
# Age:age
# University:University
# Semester: semester
#
# **********************************
#           Thank you
# **********************************

# %%
name = input("Enter your Name: ")
age = input("Enter your Age: ")
city = input("Enter your City: ")
university = input("Enter your University: ")
semester = input("Enter your Semester: ")
course = input("Enter your Course: ")

print("\n==========================================")
print("         USER PROFILE GENERATOR")
print("==========================================")

print("Name        :", name)
print("Age         :", age)
print("City        :", city)
print("University  :", university)
print("Semester    :", semester)
print("Course      :", course)

print("==========================================")
print("Profile Created Successfully")
print("==========================================")
# Out:
# Enter your Name:  Adiba Zia
# Enter your Age:  18
# Enter your City:  Lahore
# Enter your University:  GCU
# Enter your Semester:  1st Semester
# Enter your Course:  BS MATHEMATICS
# ==========================================
#          USER PROFILE GENERATOR
# ==========================================
# Name        : Adiba Zia
# Age         : 18
# City        : Lahore
# University  : GCU
# Semester    : 1st Semester
# Course      : BS MATHEMATICS
# ==========================================
# Profile Created Successfully
# ==========================================

# %% [markdown]
# # Mini Project 2

# %%
print("==========================================")
print("         JOB APPLICATION FORM")
print("==========================================")

name = input("Enter Your Full Name        : ")
qualification = input("Enter Your Qualification   : ")
skills = input("Enter Your Skills          : ")
experience = input("Enter Your Experience      : ")
email = input("Enter Your Email           : ")
phone = input("Enter Your Phone Number    : ")
city = input("Enter Your City            : ")
position = input("Enter Position Applied For : ")

print("\n==========================================")
print("        JOB APPLICATION DETAILS")
print("==========================================")

print("Applicant Name      :", name)
print("Qualification       :", qualification)
print("Skills              :", skills)
print("Experience          :", experience)
print("Email               :", email)
print("Phone Number        :", phone)
print("City                :", city)
print("Applied Position    :", position)

print("Application Submitted Successfully")
# Out:
# ==========================================
#          JOB APPLICATION FORM
# ==========================================
# Enter Your Full Name        :  Adiba Zia
# Enter Your Qualification   :  Intermediate in CS
# Enter Your Skills          :  Programming
# Enter Your Experience      :  Hands on Experience
# Enter Your Email           :  adibazia27@gamil.com
# Enter Your Phone Number    :  03********91
# Enter Your City            :  Lahore
# Enter Position Applied For :  programming
# ==========================================
#         JOB APPLICATION DETAILS
# ==========================================
# Applicant Name      : Adiba Zia
# Qualification       : Intermediate in CS
# Skills              : Programming
# Experience          : Hands on Experience
# Email               : adibazia27@gamil.com
# Phone Number        : 03********91
# City                : Lahore
# Applied Position    : programming
# Application Submitted Successfully

# %%
print("==========================================")
print("         JOB APPLICATION FORM")
print("==========================================")

name = input("Enter Your Full Name        : ")
qualification = input("Enter Your Qualification   : ")
skills = input("Enter Your Skills          : ")
experience = input("Enter Your Experience      : ")
email = input("Enter Your Email           : ")
phone = input("Enter Your Phone Number    : ")
city = input("Enter Your City            : ")
position = input("Enter Position Applied For : ")

print("\n==========================================")
print("        JOB APPLICATION DETAILS")
print("==========================================")

print("Applicant Name      :", name)
print("Qualification       :", qualification)
print("Skills              :", skills)
print("Experience          :", experience)
print("Email               :", email)
print("Phone Number        :", phone)
print("City                :", city)
print("Applied Position    :", position)

print("Application Submitted Successfully")
# Out:
# ==========================================
#          JOB APPLICATION FORM
# ==========================================
# Enter Your Full Name        :  Adiba Zia
# Enter Your Qualification   :  Intermediate in CS
# Enter Your Skills          :  Programming
# Enter Your Experience      :  Hands on Experience
# Enter Your Email           :  adibazia27@gamil.com
# Enter Your Phone Number    :  03********91
# Enter Your City            :  Lahore
# Enter Position Applied For :  programming
# ==========================================
#         JOB APPLICATION DETAILS
# ==========================================
# Applicant Name      : Adiba Zia
# Qualification       : Intermediate in CS
# Skills              : Programming
# Experience          : Hands on Experience
# Email               : adibazia27@gamil.com
# Phone Number        : 03********91
# City                : Lahore
# Applied Position    : programming
# Application Submitted Successfully

# %%
print("==========================================")
print("         JOB APPLICATION FORM")
print("==========================================")

name = input("Enter Your Full Name        : ")
qualification = input("Enter Your Qualification   : ")
skills = input("Enter Your Skills          : ")
experience = input("Enter Your Experience      : ")
email = input("Enter Your Email           : ")
phone = input("Enter Your Phone Number    : ")
city = input("Enter Your City            : ")
position = input("Enter Position Applied For : ")

print("\n==========================================")
print("        JOB APPLICATION DETAILS")
print("==========================================")

print("Applicant Name      :", name)
print("Qualification       :", qualification)
print("Skills              :", skills)
print("Experience          :", experience)
print("Email               :", email)
print("Phone Number        :", phone)
print("City                :", city)
print("Applied Position    :", position)

print("Application Submitted Successfully")
# Out:
# ==========================================
#          JOB APPLICATION FORM
# ==========================================
# Enter Your Full Name        :  Adiba Zia
# Enter Your Qualification   :  Intermediate in CS
# Enter Your Skills          :  Programming
# Enter Your Experience      :  Hands on Experience
# Enter Your Email           :  adibazia27@gmail.com
# Enter Your Phone Number    :  03*******91
# Enter Your City            :  Lahore
# Enter Position Applied For :  Programming
# ==========================================
#         JOB APPLICATION DETAILS
# ==========================================
# Applicant Name      : Adiba Zia
# Qualification       : Intermediate in CS
# Skills              : Programming
# Experience          : Hands on Experience
# Email               : adibazia27@gmail.com
# Phone Number        : 03*******91
# City                : Lahore
# Applied Position    : Programming
# Application Submitted Successfully
